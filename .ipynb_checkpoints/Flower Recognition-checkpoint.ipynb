# %%
import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import load_model
from sklearn.metrics import accuracy_score,classification_report
from matplotlib.image import imread

# %%
data_dir = "E:\\Machine Learning\\flowers-recognition\\flowers"

# %%
train_dir = data_dir + "\\train"
test_dir = data_dir + "\\test"

# %% [markdown]
# # List of species of flowers we have

# %%
for folder in os.listdir(train_dir):
    print(folder)
# Out:
# daisy
# dandelion
# rose
# sunflower
# tulip

# %% [markdown]
# # Getting a random daisy and dandelion picture

# %%
rand_daisy = os.listdir(train_dir+"\\daisy")[random.randint(0,509)]

# %%
rand_daisy
# Out:
# '34661399476_9ea7e2fd53_n.jpg'

# %%
rand_daisy = plt.imread(train_dir+"\\daisy\\"+rand_daisy)

# %%
plt.imshow(rand_daisy)

# %%
rand_dandelion = os.listdir(train_dir+"\\dandelion")[random.randint(0,509)]
rand_dandelion = plt.imread(train_dir+"\\dandelion\\"+rand_dandelion)
plt.imshow(rand_dandelion)

# %%
print(rand_daisy.shape)
print(rand_dandelion.shape)
# Out:
# (159, 240, 3)
# (333, 500, 3)

# %% [markdown]
# # Getting an appropriate input shape for our images by getting the average dimensions

# %%
dim1 = []
dim2 = []

for species in os.listdir(train_dir):
    for image_file in os.listdir(train_dir+"\\"+species):
        img = plt.imread(train_dir+"\\"+species+"\\"+image_file)
        d1,d2,colors = img.shape
        dim1.append(d1)
        dim2.append(d2)

# %%
sns.jointplot(dim1,dim2)

# %%
np.mean(dim1)
# Out:
# 249.25868342705922

# %%
np.mean(dim2)
# Out:
# 330.9381409196163

# %%
image_shape = (250,330,3)

# %% [markdown]
# # Making an Image Generator and seeing how it transforms a random dandelion image

# %%
image_gen = ImageDataGenerator(rotation_range = 20,                         
                              width_shift_range=0.1,    
                              height_shift_range=0.1,
                               rescale=1/255,
                              shear_range= 0.1,             
                              zoom_range=0.1,              
                              horizontal_flip=True,        
                               fill_mode = 'nearest')

# %%
plt.imshow(rand_dandelion)

# %%
plt.imshow(image_gen.random_transform(rand_dandelion))

# %%
image_gen.flow_from_directory(train_dir)
# Out:
# Found 3023 images belonging to 5 classes.

# %%
image_gen.flow_from_directory(test_dir)
# Out:
# Found 1300 images belonging to 5 classes.

# %% [markdown]
# # Making our model

# %%
model = Sequential()

model.add(Conv2D(filters = 16, kernel_size = (5,5),padding = 'same',activation ='relu', input_shape = image_shape))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Conv2D(filters =64, kernel_size = (3,3),padding = 'same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.2))

model.add(Conv2D(filters = 128, kernel_size = (3,3),padding = 'same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.2))

model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.2))

model.add(Conv2D(filters = 16, kernel_size = (3,3),padding = 'same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Flatten())

model.add(Dense(512,activation='relu'))

model.add(Dense(5, activation = "softmax"))

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 250, 330, 16)      1216
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 125, 165, 16)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 125, 165, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 125, 165, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 62, 82, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 62, 82, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 31, 41, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 31, 41, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 31, 41, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 15, 20, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 15, 20, 64)        73792
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 10, 64)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 7, 10, 64)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 7, 10, 32)         18464
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 3, 5, 32)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 3, 5, 32)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 3, 5, 16)          4624
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 1, 2, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 512)               16896
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 2565
# =================================================================
# Total params: 214,549
# Trainable params: 214,549
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 16

# %% [markdown]
# # Generating our training and test images

# %%
train_image_gen = image_gen.flow_from_directory(train_dir,target_size=image_shape[:2],
                                               color_mode='rgb',
                                               batch_size=batch_size,
                                               class_mode='categorical')
# Out:
# Found 3023 images belonging to 5 classes.

# %%
test_image_gen = image_gen.flow_from_directory(test_dir,target_size=image_shape[:2],
                                               color_mode='rgb',
                                               batch_size=batch_size,
                                               class_mode='categorical',
                                              shuffle = False)
# Out:
# Found 1300 images belonging to 5 classes.

# %%
train_image_gen.class_indices
# Out:
# {'daisy': 0, 'dandelion': 1, 'rose': 2, 'sunflower': 3, 'tulip': 4}

# %%
stop = EarlyStopping(patience = 3, monitor = 'val_loss')

# %% [markdown]
# # Training

# %%
results = model.fit_generator(train_image_gen,
                             epochs=100,
                             validation_data=test_image_gen,
                             callbacks = [stop])
# Out:
# Epoch 1/100
# 189/189 [==============================] - 73s 384ms/step - loss: 1.4054 - accuracy: 0.3850 - val_loss: 1.3114 - val_accuracy: 0.3846
# Epoch 2/100
# 189/189 [==============================] - 73s 386ms/step - loss: 1.2525 - accuracy: 0.4591 - val_loss: 1.2773 - val_accuracy: 0.4531
# Epoch 3/100
# 189/189 [==============================] - 75s 396ms/step - loss: 1.1937 - accuracy: 0.5117 - val_loss: 1.2761 - val_accuracy: 0.4623
# Epoch 4/100
# 189/189 [==============================] - 77s 407ms/step - loss: 1.0932 - accuracy: 0.5667 - val_loss: 1.2003 - val_accuracy: 0.5092
# Epoch 5/100
# 189/189 [==============================] - 77s 408ms/step - loss: 1.0642 - accuracy: 0.5726 - val_loss: 1.2540 - val_accuracy: 0.5131
# Epoch 6/100
# 189/189 [==============================] - 77s 409ms/step - loss: 1.0170 - accuracy: 0.6017 - val_loss: 1.1523 - val_accuracy: 0.5485
# Epoch 7/100
# 189/189 [==============================] - 78s 410ms/step - loss: 1.0108 - accuracy: 0.6080 - val_loss: 1.2202 - val_accuracy: 0.5062
# Epoch 8/100
# 189/189 [==============================] - 81s 427ms/step - loss: 0.9573 - accuracy: 0.6219 - val_loss: 0.9982 - val_accuracy: 0.5954
# Epoch 9/100
# 189/189 [==============================] - 78s 412ms/step - loss: 0.9413 - accuracy: 0.6318 - val_loss: 1.0891 - val_accuracy: 0.5638
# Epoch 10/100
# 189/189 [==============================] - 79s 418ms/step - loss: 0.9061 - accuracy: 0.6460 - val_loss: 0.9916 - val_accuracy: 0.6200
# Epoch 11/100
# 189/189 [==============================] - 84s 442ms/step - loss: 0.8862 - accuracy: 0.6589 - val_loss: 1.0148 - val_accuracy: 0.6123
# Epoch 12/100
# 189/189 [==============================] - 80s 424ms/step - loss: 0.8603 - accuracy: 0.6801 - val_loss: 0.9191 - val_accuracy: 0.6592
# Epoch 13/100
# 189/189 [==============================] - 80s 423ms/step - loss: 0.8483 - accuracy: 0.6761 - val_loss: 0.9060 - val_accuracy: 0.6685
# Epoch 14/100
# 189/189 [==============================] - 80s 425ms/step - loss: 0.8177 - accuracy: 0.6854 - val_loss: 0.9502 - val_accuracy: 0.6523
# Epoch 15/100
# 189/189 [==============================] - 80s 421ms/step - loss: 0.7773 - accuracy: 0.6970 - val_loss: 0.8826 - val_accuracy: 0.6792
# Epoch 16/100
# 189/189 [==============================] - 82s 433ms/step - loss: 0.7804 - accuracy: 0.7079 - val_loss: 0.9105 - val_accuracy: 0.6669
# Epoch 17/100
# 189/189 [==============================] - 86s 454ms/step - loss: 0.7640 - accuracy: 0.7135 - val_loss: 0.8601 - val_accuracy: 0.6931
# Epoch 18/100
# 189/189 [==============================] - 88s 466ms/step - loss: 0.7536 - accuracy: 0.7215 - val_loss: 0.8167 - val_accuracy: 0.7062
# Epoch 19/100
# 189/189 [==============================] - 90s 479ms/step - loss: 0.7156 - accuracy: 0.7327 - val_loss: 0.8135 - val_accuracy: 0.7015
# Epoch 20/100
# 189/189 [==============================] - 88s 465ms/step - loss: 0.7320 - accuracy: 0.7225 - val_loss: 0.7886 - val_accuracy: 0.6908
# Epoch 21/100
# 189/189 [==============================] - 87s 460ms/step - loss: 0.7122 - accuracy: 0.7413 - val_loss: 0.7794 - val_accuracy: 0.7215
# Epoch 22/100
# 189/189 [==============================] - 88s 463ms/step - loss: 0.6939 - accuracy: 0.7370 - val_loss: 0.7477 - val_accuracy: 0.7177
# Epoch 23/100
# 189/189 [==============================] - 93s 492ms/step - loss: 0.6771 - accuracy: 0.7433 - val_loss: 0.7393 - val_accuracy: 0.7362
# Epoch 24/100
# 189/189 [==============================] - 83s 441ms/step - loss: 0.6770 - accuracy: 0.7450 - val_loss: 0.7017 - val_accuracy: 0.7477
# Epoch 25/100
# 189/189 [==============================] - 85s 450ms/step - loss: 0.6589 - accuracy: 0.7473 - val_loss: 0.8580 - val_accuracy: 0.7138
# Epoch 26/100
# 189/189 [==============================] - 91s 481ms/step - loss: 0.6470 - accuracy: 0.7582 - val_loss: 0.7796 - val_accuracy: 0.7100
# Epoch 27/100
# 189/189 [==============================] - 95s 505ms/step - loss: 0.6253 - accuracy: 0.7708 - val_loss: 0.7082 - val_accuracy: 0.7554

# %%
history = pd.DataFrame(model.history.history)

# %% [markdown]
# # Plotting accuracy and validation accuracy

# %%
history[['accuracy','val_accuracy']].plot()

# %% [markdown]
# # Plotting loss and validation loss

# %%
history[['loss','val_loss']].plot()

# %% [markdown]
# # Getting predictions which predict the probabilty of each class then turning the class with the highest probabilty as the prediction

# %%
pred_prob = model.predict_generator(test_image_gen)

# %%
pred_prob
# Out:
# array([[1.50956690e-01, 7.34328032e-01, 2.24687103e-02, 6.44851401e-02,
#         2.77614594e-02],
#        [8.68201613e-01, 1.09228298e-01, 1.64290087e-03, 1.36503996e-02,
#         7.27682887e-03],
#        [2.60763556e-01, 3.19522262e-01, 1.08555935e-01, 7.40967616e-02,
#         2.37061456e-01],
#        ...,
#        [6.42340481e-02, 1.70587387e-03, 2.33353227e-01, 2.03459803e-03,
#         6.98672295e-01],
#        [4.41909343e-01, 1.25192508e-01, 2.98760563e-01, 6.01697993e-03,
#         1.28120556e-01],
#        [5.32190199e-04, 1.68138849e-05, 4.56146570e-03, 4.72198124e-04,
#         9.94417310e-01]], dtype=float32)

# %%
preds = pred_prob.argmax(axis=-1)

# %%
preds
# Out:
# array([1, 0, 1, ..., 4, 0, 4], dtype=int64)

# %% [markdown]
# # Checking model accuracy

# %%
print(test_image_gen.classes)
# Out:
# [0 0 0 ... 4 4 4]

# %%
print(classification_report(test_image_gen.classes,preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.81      0.80       260
#            1       0.67      0.86      0.75       260
#            2       0.80      0.54      0.65       260
#            3       0.81      0.87      0.84       260
#            4       0.71      0.67      0.69       260
#
#     accuracy                           0.75      1300
#    macro avg       0.76      0.75      0.75      1300
# weighted avg       0.76      0.75      0.75      1300

# %%
print("Accuracy of the model: "+str(round(accuracy_score(test_image_gen.classes,preds)*100,2))+" %")
# Out:
# Accuracy of the model: 75.0 %
